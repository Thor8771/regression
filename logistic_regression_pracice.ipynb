# %%
import pandas as pd

# %%
data=pd.read_csv('s.csv')

# %%
data
# Out:
#         Id  SalePrice
# 0     1461     125000
# 1     1462     272000
# 2     1463     192000
# 3     1464     189000
# 4     1465     189000
# ...    ...        ...
# 1454  2915      97000
# 1455  2916      88000
# 1456  2917     149900
# 1457  2918     148000
# 1458  2919     188000
#
# [1459 rows x 2 columns]

# %%
data.head(2)
# Out:
#      Id  SalePrice
# 0  1461     125000
# 1  1462     272000

# %%
import matplotlib.pyplot as plt
plt.scatter(x=data['Id'],y=data['SalePrice'])
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(data[['Id']],data['SalePrice'] ,test_size=0.2)

# %%
x_test
# Out:
#         Id
# 73    1534
# 426   1887
# 81    1542
# 103   1564
# 423   1884
# ...    ...
# 210   1671
# 327   1788
# 1214  2675
# 995   2456
# 570   2031
#
# [292 rows x 1 columns]

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score
ac=accuracy_score(model.predict(x_test),y_test)

# %%
ac
# Out:
# 0.02054794520547945

# %%
plt.show()

# %%
data.head(5)
# Out:
#      Id  SalePrice
# 0  1461     125000
# 1  1462     272000
# 2  1463     192000
# 3  1464     189000
# 4  1465     189000
